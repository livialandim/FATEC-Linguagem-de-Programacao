# %% [markdown]
# ### 1. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia um número e o multiplique por 2 retornando o resultado e o apresente.

# %%
def multiplicar():
    numero = int(input('Digite um valor: '))
    resultado = numero * 2
    return resultado # sai da lógica da função e devolve um valor à ela.

def main():
    print('entrei na main')
    r = multiplicar()
    print('Resultado com uma variável: ',r)

main()

# Formas de chamar uma função return:
# Se colocar apenas o 'multiplicar()' não acontecerá nada visivelmente, já que não há um 'print()'
# 1) r = multiplicar()
# 2) print('Texto', multiplicar())

# Quando uma função possui 'return' é possível armazená-la numa variável
# Out:
# entrei na main
# Digite um valor: 6
# Resultado com uma variável:  (12, 6)

# %% [markdown]
# ### 2. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método para subtrair dois números, retornar o resultado e o apresentando.

# %%
def subtracao() :
    numero1 = int(input('Informe um valor a ser subtraído '))
    numero2 = int(input('Informe outro valor a ser subtraído '))

    subtrair = numero1 - numero2

    return subtrair

def main() :
    print('O resultado dessa subtração é: ', subtracao() )

main()
# Out:
# Informe um valor a ser subtraído 10
# Informe outro valor a ser subtraído 4
# O resultado dessa subtração é:  6

# %% [markdown]
# ### 3. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia a base e a altura de um triângulo e retorne/apresente sua área A = (base x altura)/2.

# %%
def calculo() :
    base = float(input('Informe a base do triângulo: '))
    altura = float(input('Informe a altura do triângulo: '))

    area = (base * altura) / 2

    return area

def main() :
    print('O valor da área do triângulo é ', calculo())

main()
# Out:
# Informe a base do triângulo: 3
# Informe a altura do triângulo: 4
# O valor da área do triângulo é  6.0

# %% [markdown]
# ### 4. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia o lado de um quadrado e retorne sua área, area = lado².

# %%
def calculo() :
    lado = float(input('Informe o valor do lado do quadrado: '))

    area = lado * lado

    return area

def main() :
    print('A área do quadrado vale: ', calculo())

main()
# Out:
# Informe o valor do lado do quadrado: 25
# A área do quadrado vale:  625.0

# %% [markdown]
# ###5. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne mostrando a str/string ‘É par’ ou se ‘É ímpar’.

# %%
def verificacao() :
    numero = int(input('Informe um valor: '))

    divisao = numero % 2

    return divisao

def main() :
    if verificacao() == 0:
        print('É par')
    else:
        print('É ímpar')

main()
# Out:
# Informe um valor: 2
# É par

# %%
def verificacao() :
    numero = int(input('Informe um valor: '))
    # Expressão condicional / Operador ternário
    return 'É par' if numero % 2 == 0 else 'É ímpar'

def main() :
    print(verificacao())
main()
# Out:
# Informe um valor: 4
# É par

# %% [markdown]
# ###6. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne/mostre o valor bool **True** para par e **False** para ímpar.

# %%
def verificacao() :
    numero = int(input('Informe um valor: '))

    divisao = numero % 2

    if divisao == 0:
        return True
    else:
        return False

def main() :
    print('O valor é ',verificacao())
main()
# Out:
# Informe um valor: 5
# False

# %%
def verificacao() :
    numero = int(input('Informe um valor: '))
    # Expressão condicional / Operador ternário
    return True if numero % 2 == 0 else False

def main() :
    print('O valor é ',verificacao())
main()

# %% [markdown]
# ### 7. (Função com retorno sem parâmetro) Faça uma função/método que leia e armazene 5 elementos inteiros no vetor A, deverá ser gerado um vetor B, de mesmo tamanho, que armazenará o fatorial de cada elemento de A. Não use função pronta de cálculo de fatorial. Retorne/apresente o vetor B.

# %%
# Exemplo:
# A = [5  ,4 ,3,2,1]
# B = [120,24,6,2,1]

def vetores() :
    a = []
    b = []

    for i in range(5):
        a.append(int(input('Informe um número inteiro: ')))

    for i in range(5) :
        fatorial = 1
        while a[i] >= 1 :
            fatorial = fatorial * a[i]
            a[i] -= 1
        b.append(fatorial)

    return b

def main() :
    print(vetores())

main()
# Out:
# Informe um número inteiro: 5
# Informe um número inteiro: 4
# Informe um número inteiro: 3
# Informe um número inteiro: 2
# Informe um número inteiro: 1
# [120, 24, 6, 2, 1]

# %% [markdown]
# ### 8. (Função com retorno sem parâmetro) Faça uma função/método retorne um vetor com os três primeiros números perfeitos. Sabe-se que um número é perfeito quando é igual a soma de seus divisores (exceto ele mesmo).
# Exemplo: os divisores de 6 são 1, 2 e 3, e 1 + 2 + 3 = 6, logo 6 é perfeito. Não use função pronta.
#
# 1º número perfeito: 6
#
# 2º número perfeito: 28
#
# 3º número perfeito: 496

# %%
# número 1 não é perfeito
# ...
# número 4 não é perfeito, exemplo: 4 % 1 == 0, 4 % 2 == 0, 4 % 3 != 0, a soma
# resulta em 2
# ...
# número 6 é perfeito  6 % 1 == 0, 6 % 2 == 0, 6 % 3 == 0, 6 % 4 != 0, 6 % 5 != 0
# quando é perfeito a soma de seus divisores da o mesmo valor de número que é 6


numeroPerfeito = []

def divisao() :
    for n in range(1, 497) :
        i = 1
        somaDivisor = 0
        while i < n :
            divisor = n % i
            if divisor == 0 :
                somaDivisor += i
            i += 1
        if somaDivisor == n:
            numeroPerfeito.append(n)

    return numeroPerfeito

def main() :
    print(divisao())

main()
# Out:
# [6, 28, 496]

# %% [markdown]
# ### 9. (Função com retorno sem parâmetro) Foi realizada uma pesquisa sobre algumas características físicas de cinco habitantes de uma região. Foram coletados os seguintes dados de cada habitante: idade, sexo (M - masculino ou F - feminino), cor dos olhos (A - azuis ou C - castanhos), cor dos cabelos (L - louros, P - pretos ou C - castanhos).
#
# 1.   Faça uma função/método que leia esses dados, armazenando-os em vetores (listas);
# 2.   Faça uma função/método que determine e devolva a função principal a média de idades das pessoas com olhos castanhos e cabelos pretos;
# 3. Faça uma função/método que determine e devolva a função principal a maior idade entre os habitantes;
# 4.  Faça uma função/método que determine e devolva a função principal a quantidade de indivíduos do sexo feminino com idade entre 18 e 35 anos(inclusive) e que tenham olhos azuis e cabelos louros.

# %%
# Declarar os vetores antes de qualquer programação, indica que
# que estas variáveis serão globais a todo o restante do programa
# e das funções

idade = []
sexo = []
olho = []
cabelo = []

def cadastrar() :
    for i in range(5) :
        idade.append(int(input('Informe a idade do cidadão: ')))
        sexo.append(input('Informe o gênero do cidadão (M/F): '))
        olho.append(input('Informe a cor dos olhos do cidadão (A/C): '))
        cabelo.append(input('Informe a cor dos cabelos do cidadão (L/P/C): '))

def media() :
    soma = 0
    divisor = 0
    for i in range(len(olho)) :
        if olho[i] == 'C' or olho[i] == 'c' and cabelo[i] == 'P' or cabelo[i] == 'p' :
            soma += idade[i]
            divisor += 1
        mediaAzulPreto = soma / divisor
        return mediaAzulPreto

def idades() :
    for i in range(len(olho)) :
        if i == 0 :
            maisVelho = idade[0]
        else :
            if idade[i] >= maisVelho :
                maisVelho = idade[i]
                return maisVelho

def quantidade() :
    for i in range(len(sexo)) :
        if sexo[i] == 'F' or sexo[i] == 'f':
            if idade[i] >= 18 and idade[i] <= 35 :
                if olho[i] == 'A' or olho[i] == 'a':
                    if cabelo == 'L' or cabelo == 'l' :
                        somaF += 1
                        return somaF

def main():
    cadastrar()

    print()

    print('A média de idade entre pessoas de olhos castanhos e cabelos pretos é ', media())

    print()

    print('A maior idade entre os habitantes é ', idades())

    print()

    print('A quantidade de mulheres com idade entre 18 a 35 anos, de cabelos loiros e olhos azuis é ', quantidade())

main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-96fe2773d19e> in <cell line: 60>()
#      58     print('A quantidade de mulheres com idade entre 18 a 35 anos, de cabelos loiros e olhos azuis é ', quantidade())
#      59
# ---> 60 main()
#
# <ipython-input-5-96fe2773d19e> in main()
#      44
#      45 def main():
# ---> 46     cadastrar()
#      47
#      48     print()
#
# <ipython-input-5-96fe2773d19e> in cadastrar()
#      10 def cadastrar() :
#      11     for i in range(2) :
# ---> 12         idade.append(int(input('Informe a idade do cidadão: ')))
#      13         sexo.append(input('Informe o gênero do cidadão (M/F): '))
#      14         olho.append(input('Informe a cor dos olhos do cidadão (A/C): '))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
